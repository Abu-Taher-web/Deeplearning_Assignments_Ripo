# %% [markdown]
# # Deep Learning 2024 - Assignment 1
#
# Designed by Marko Savic (marko.savic@oulu.fi)

# %% [markdown]
# ## Outline (10 points)
# #### Submission:
# We will give 2 weeks for each assignment and more for the final project.
#
# The grades will be released after the deadline. Please also put your name and student number (if you have one) in the file name of the returned assignments. (DL2024_assign1_NAME_SURNAME_STUDENTNUMBER.ipynb)
#
# #### In this assignment, you will learn:
# * How to load data and create a train/test split
# * How to build your own Pytorch model for simple linear regression problem on the generated data.
# * Training the model with gradient descent algorithm in Pytorch.
# * Simple visualisation of data, loss and linear model
#
# #### Tasks (10 points):
# * Part 1. Load dataset and split into training and testing sets (1.5 points)
# * Part 2.1 Model (1.5 points)
# * Part 2.2 Training (7 points)
#
# #### Environment
# Python 3 + Pytorch (>=1.3).<br>
# Other libraries should be installed correctly such as numpy, matplotlib, *etc*., according to the dependencies of the assignment. <br>
# If you haven’t installed Pytorch and Jupyter notebook in your computer, an alternative environment to finish the assignment is CSC notebook: [`https://noppe.2.rahtiapp.fi/`](https://noppe.2.rahtiapp.fi/) -> log in with HaKa using your university account -> Jupyter Machine Learning.
# Also, googlecolab is available through your google university account (instruction in https://www.oulu.fi/en/for-students/supporting-your-studies-and-contact-information-for-students/it-services-for-students/google-workspace-for-education). Computer room TS135 contains computers with GPUs that you can utilise as well.
#
# We will give 2 weeks for each assignment and more for the final project. So it may happen where the new assignment is published before the deadline of the previous assignment. Please do not wait till the last minute to complete the assigments, as they can be time consuming.
#
# #### Database
# * Advertising dataset
#
# #### Hints
# * To find the place where you have to insert your solution, hit Crtl + F and search for **TODO:** . You are not supposed to modify the code from other parts.
# * Be careful with the shape of the weights, gradient, .. of your tensor in your implementation. Double check and make sure the shapes fit for computation, especially matrix multiplication.
# * Use only torch functions for the model, and avoid iterations. E.g. if you put a for cycle in the model function then parallelism is gone and your model will not run efficiently on GPUs. Also once you have the data loaded as tensors, you need to use torch functions, if you convert to numpy arrays in the training loop then it will not train efficiently.
# * Check the examples from the pytorch tutorial lecture, they can help understand the assignment better.

# %% [markdown]
# ## Part 1. Load dataset and split into training and testing sets
#
# Suppose we observe a set of n real-valued input variables x = $\{x_n\}$ and wish to use this observation to predict
# the value of a real-valued target variable $y$. In the tutorial we considered artifical examples with synthetic data. In this exercise we will consider a simple dataset that is suitable for linear regression.
#
# We will take a small advertisement dataset. It contains data on the budget allocated for TV, radio and newspaper advertisements with the resulting sales. It contains n = 200 samples with three variables "TV", "Radio","Newspaper" and the value we want to predict, that is "Sales". Assuming a linear model is a good representation of the correlation between advertisement budgets and final sales, we will try to train a linear model to regress the sales based on advertisement budget.
#
# The dataset is located in the advertisement .csv file and opened as a pandas Dataframe. Firstly we will turn the input variables and regression target into Tensors, and then split the data into training and testing sets. In this case we choose a five fold split, meaning we will use 20% of the data for testing (last 40 samples) and 80% for training (first 160 samples).
#
# Please create the required training and testing data below and plot the relationship between the feature 'TV' and the target. Since we have 3 different features, we will only pick 'TV' a 2D plot.

# %%
# !pip install onedrivedownloader

from onedrivedownloader import download
import os
link = 'https://unioulu-my.sharepoint.com/:x:/g/personal/msavic21_univ_yo_oulu_fi/Eb211jNyQAVIhTq1HsoxQyEBEqoDNHhr606Kfh9LY5Brjw?e=cONlaG'

#if not os.path.exists('./data/fashion_mnist_npy'):
#    print('Downloading dataset')
download(link, filename="./advertising.csv", unzip=True, unzip_path='./')
# Out:
# Collecting onedrivedownloader
#   Downloading onedrivedownloader-1.1.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2024.8.30)
# Downloading onedrivedownloader-1.1.3-py3-none-any.whl (5.1 kB)
# Installing collected packages: onedrivedownloader
# Successfully installed onedrivedownloader-1.1.3
# 100%|██████████| 4.06k/4.06k [00:00<00:00, 6.06MiB/s]
# './advertising.csv'

# %%
import matplotlib.pyplot as plt
import torch.nn as nn
import torch
import numpy as np
import pandas as pd

adv_dataset=pd.read_csv('./advertising.csv')
adv_dataset.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# TODO: (1.5 points, details are given below):
from sklearn.model_selection import train_test_split
# get the relevant data from the adv_dataset dataframe and assign them to the Tensors x (feature variables) and y (target)  (0.5 point)
# YOUR CODE HERE
x = torch.tensor(adv_dataset[['TV', 'Radio', 'Newspaper']].values, dtype=torch.float32)
y = torch.tensor(adv_dataset['Sales'].values, dtype=torch.float32).view(-1,1)
print(x.size(),y.size())


# divide the data in a train set (80% of the data) and test set (20% of the data). Resulting in x_train, x_test, y_train, y_test (0.5 point)
# YOUR CODE HERE
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(x_train.size(),y_train.size())
print(x_test.size(),y_test.size())


# plot the first feature 'TV' in relationship with the target y. Train and test data should be in a single figure with two different colors (0.5 point)
# YOUR CODE HERE
plt.figure(figsize=(16, 8))
plt.scatter(x_train[:, 0], y_train, color='blue', label='Train Data', s=10)
plt.scatter(x_test[:, 0], y_test, color='red', label='Test Data')
plt.xlabel('TV Advertising Budget')
plt.ylabel('Sales')
plt.title('TV vs Sales: Training and Testing Data')
plt.legend()
plt.show()
# Out:
# torch.Size([200, 3]) torch.Size([200, 1])
# torch.Size([160, 3]) torch.Size([160, 1])
# torch.Size([40, 3]) torch.Size([40, 1])

# %% [markdown]
# ## Part 2. Solving the linear regression problem in Pytorch using Gradient Descent Algorithm
# Congratulations you have prepared the data correctly! Now we will move onto creating our model and training it.

# %% [markdown]
# ### 2.1 Model
# In this part, you will define your own model class. To do that, you have to remember the following rules:
# 1. The model class should be inherited from [`nn.Module`](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module);
# 2. Re-write the **\_\_init\_\_** function and the **forward** function;
# 3. In the **\_\_init\_\_** function, you should always call the parent's **\_\_init\_\_** function first.
# 4. Don't use the nn.Linear() layer, implement it yourself.
# 5. Use 1 tensor to define w (not 3) and 1 tensor to define b.
# 6. Only torch functions and no iterations inside the model.
#
# To make it simpler, since we are using a linear function to approximate the phenomenon that generated the data, our function will be:
#
# \begin{align*}
# y = w^T x + b
# \end{align*}
#
# Therefore, in the model, we need to set 2 parameters: $w$, $b$

# %%
# TODO (1.5 points, details are given below)
import torch.nn as nn


# define a class (0.5) + write the __init__ function (0.5 point) + write the forward function (0.5 points)

# YOUR CODE HERE

class LinearRegressionModel(nn.Module):
    def __init__(self, input_dim):
        super().__init__()

        self.w =  nn.Parameter(torch.randn(input_dim, 1, requires_grad=True))
        self.b =  nn.Parameter(torch.randn(1, requires_grad=True))

    def forward(self, x):
        y = torch.matmul(x, self.w) + self.b
        return y

# %% [markdown]
# ### 2.2 Training
# Here, you will train your model based on the training data and evaluate the model on testing data.
# 1. Set proper number of iterations and learning rate.
# 2. Remember to use a proper optimizer (you may have many choices: Adam, SGD, RMSprop, ... please find the detailed information in https://pytorch.org/docs/stable/optim.html and know how to use them).
# 3. In order to train the model, a loss function should be defined:
# \begin{align*}
# loss = \frac{1}{N}\sum_{i=1}^{N}|f_i - y_i|,
# \end{align*}
# where, $f_i$ is the output of the model and $N$ is the number of training data pairs.
# 4. The model must be trained only using training data.
# 5. Remember to clear the old gradients of parameters before a new backward propagation.
# 6. In every certain number of iterations, print the values of the parameters, the training loss, and the testing loss.
# 7. Meanwhile, please track the training loss and the testing loss in each iteration. Once the training is done, the curves of losses should be plotted (two curves are drawn in the same figure, where x axis indicates iterations and y axis indicates the losses).
# 8. Lastly, draw all the training data, testing data and the curve of the trained model in the same figure (use different showing styles to distinguish them).

# %%
# TODO (7 points, details are given below)

# Make a instance of the model class (0.5 point)
# YOUR CODE HERE
model = LinearRegressionModel(x_train.shape[1])

# create an optimizer, set a workable learing rate (1 point)
# YOUR CODE HERE
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

def loss_function(y_pred, y_true):
    return torch.mean(torch.abs(y_true - y_pred))

training_losses = []
testing_losses = []

n_itr = 10000

for i in range(n_itr):

    # Train
    # forward propagation
    model.train() # change model to train mode

    # calculate the output of model (0.5 point)
    # YOUR CODE HERE
    y_train_pred = model(x_train)

    # calculate loss according to the above equation (1 point)
    # YOUR CODE HERE
    loss = loss_function(y_train_pred, y_train)
    training_losses.append(loss.item())


    # backward propagation (clear old gradients, calculate gradients of parameters, gradient descent algorithm ) (1.5 point)
    # YOUR CODE HERE
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Evaluate, calculate the testing loss (1 point)
    model.eval() # change model to eval mode

    # YOUR CODE HERE
    model.eval()  # Change model to evaluation mode
    with torch.no_grad():
        y_test_pred = model(x_test)
        test_loss = loss_function(y_test_pred, y_test)
        testing_losses.append(test_loss.item())

    # print intermediate losses for certain iterations (0.5 point)
    if i % 100 == 1:
        print('Iteration: %04d | Training loss: %f | Testing loss: %f' % \
              (i, loss.data, test_loss.data))
# Out:
# Iteration: 0001 | Training loss: 52.013874 | Testing loss: 46.643784
# Iteration: 0101 | Training loss: 35.588440 | Testing loss: 31.793713
# Iteration: 0201 | Training loss: 24.544846 | Testing loss: 22.268406
# Iteration: 0301 | Training loss: 19.066677 | Testing loss: 18.896511
# Iteration: 0401 | Training loss: 15.500107 | Testing loss: 15.889722
# Iteration: 0501 | Training loss: 12.262860 | Testing loss: 13.000216
# Iteration: 0601 | Training loss: 9.317711 | Testing loss: 10.357934
# Iteration: 0701 | Training loss: 6.664599 | Testing loss: 8.129984
# Iteration: 0801 | Training loss: 4.759345 | Testing loss: 6.095642
# Iteration: 0901 | Training loss: 3.334517 | Testing loss: 4.263767
# Iteration: 1001 | Training loss: 2.363353 | Testing loss: 3.046773
# Iteration: 1101 | Training loss: 1.881922 | Testing loss: 2.272509
# Iteration: 1201 | Training loss: 1.708583 | Testing loss: 1.884163
# Iteration: 1301 | Training loss: 1.646990 | Testing loss: 1.720265
# Iteration: 1401 | Training loss: 1.623299 | Testing loss: 1.676587
# Iteration: 1501 | Training loss: 1.603834 | Testing loss: 1.652318
# Iteration: 1601 | Training loss: 1.585865 | Testing loss: 1.629104
# Iteration: 1701 | Training loss: 1.567808 | Testing loss: 1.606700
# Iteration: 1801 | Training loss: 1.550817 | Testing loss: 1.587438
# Iteration: 1901 | Training loss: 1.533956 | Testing loss: 1.567991
# Iteration: 2001 | Training loss: 1.519578 | Testing loss: 1.553546
# Iteration: 2101 | Training loss: 1.506209 | Testing loss: 1.542050
# Iteration: 2201 | Training loss: 1.492696 | Testing loss: 1.526393
# Iteration: 2301 | Training loss: 1.479169 | Testing loss: 1.510223
# Iteration: 2401 | Training loss: 1.466061 | Testing loss: 1.503090
# Iteration: 2501 | Training loss: 1.452810 | Testing loss: 1.497169
# Iteration: 2601 | Training loss: 1.439410 | Testing loss: 1.490800
# Iteration: 2701 | Training loss: 1.425821 | Testing loss: 1.484435
# Iteration: 2801 | Training loss: 1.412051 | Testing loss: 1.477733
# Iteration: 2901 | Training loss: 1.398196 | Testing loss: 1.471930
# Iteration: 3001 | Training loss: 1.384683 | Testing loss: 1.455707
# Iteration: 3101 | Training loss: 1.371275 | Testing loss: 1.436468
# Iteration: 3201 | Training loss: 1.357721 | Testing loss: 1.418676
# Iteration: 3301 | Training loss: 1.344151 | Testing loss: 1.401046
# Iteration: 3401 | Training loss: 1.330424 | Testing loss: 1.386867
# Iteration: 3501 | Training loss: 1.317970 | Testing loss: 1.372760
# Iteration: 3601 | Training loss: 1.307384 | Testing loss: 1.360713
# Iteration: 3701 | Training loss: 1.297611 | Testing loss: 1.346336
# Iteration: 3801 | Training loss: 1.288562 | Testing loss: 1.345284
# Iteration: 3901 | Training loss: 1.280284 | Testing loss: 1.336246
# Iteration: 4001 | Training loss: 1.271893 | Testing loss: 1.328709
# Iteration: 4101 | Training loss: 1.263674 | Testing loss: 1.322489
# Iteration: 4201 | Training loss: 1.256863 | Testing loss: 1.321547
# Iteration: 4301 | Training loss: 1.250625 | Testing loss: 1.332090
# Iteration: 4401 | Training loss: 1.245076 | Testing loss: 1.330781
# Iteration: 4501 | Training loss: 1.239870 | Testing loss: 1.345850
# Iteration: 4601 | Training loss: 1.236449 | Testing loss: 1.344632
# Iteration: 4701 | Training loss: 1.232968 | Testing loss: 1.342728
# Iteration: 4801 | Training loss: 1.229997 | Testing loss: 1.336426
# Iteration: 4901 | Training loss: 1.227915 | Testing loss: 1.335154
# Iteration: 5001 | Training loss: 1.225841 | Testing loss: 1.329454
# Iteration: 5101 | Training loss: 1.223692 | Testing loss: 1.328537
# Iteration: 5201 | Training loss: 1.222461 | Testing loss: 1.327755
# Iteration: 5301 | Training loss: 1.221664 | Testing loss: 1.319703
# Iteration: 5401 | Training loss: 1.220641 | Testing loss: 1.318538
# Iteration: 5501 | Training loss: 1.219765 | Testing loss: 1.314781
# Iteration: 5601 | Training loss: 1.218713 | Testing loss: 1.312661
# Iteration: 5701 | Training loss: 1.218210 | Testing loss: 1.305534
# Iteration: 5801 | Training loss: 1.218144 | Testing loss: 1.312550
# Iteration: 5901 | Training loss: 1.218396 | Testing loss: 1.301006
# Iteration: 6001 | Training loss: 1.217621 | Testing loss: 1.316171
# Iteration: 6101 | Training loss: 1.217464 | Testing loss: 1.311307
# Iteration: 6201 | Training loss: 1.217422 | Testing loss: 1.297234
# Iteration: 6301 | Training loss: 1.217515 | Testing loss: 1.303603
# Iteration: 6401 | Training loss: 1.217282 | Testing loss: 1.300586
# Iteration: 6501 | Training loss: 1.217348 | Testing loss: 1.292117
# Iteration: 6601 | Training loss: 1.217238 | Testing loss: 1.296260
# Iteration: 6701 | Training loss: 1.217114 | Testing loss: 1.289030
# Iteration: 6801 | Training loss: 1.217144 | Testing loss: 1.288338
# Iteration: 6901 | Training loss: 1.217279 | Testing loss: 1.289157
# Iteration: 7001 | Training loss: 1.217128 | Testing loss: 1.283786
# Iteration: 7101 | Training loss: 1.217000 | Testing loss: 1.278515
# Iteration: 7201 | Training loss: 1.217184 | Testing loss: 1.284884
# Iteration: 7301 | Training loss: 1.217156 | Testing loss: 1.288865
# Iteration: 7401 | Training loss: 1.217049 | Testing loss: 1.289133
# Iteration: 7501 | Training loss: 1.217333 | Testing loss: 1.293368
# Iteration: 7601 | Training loss: 1.217233 | Testing loss: 1.278671
# Iteration: 7701 | Training loss: 1.217160 | Testing loss: 1.276119
# Iteration: 7801 | Training loss: 1.217249 | Testing loss: 1.288573
# Iteration: 7901 | Training loss: 1.217080 | Testing loss: 1.283013
# Iteration: 8001 | Training loss: 1.217054 | Testing loss: 1.275932
# Iteration: 8101 | Training loss: 1.217071 | Testing loss: 1.278715
# Iteration: 8201 | Training loss: 1.217214 | Testing loss: 1.286755
# Iteration: 8301 | Training loss: 1.217558 | Testing loss: 1.273050
# Iteration: 8401 | Training loss: 1.217036 | Testing loss: 1.274041
# Iteration: 8501 | Training loss: 1.217049 | Testing loss: 1.283689
# Iteration: 8601 | Training loss: 1.217067 | Testing loss: 1.281254
# Iteration: 8701 | Training loss: 1.217088 | Testing loss: 1.281569
# Iteration: 8801 | Training loss: 1.217161 | Testing loss: 1.288110
# Iteration: 8901 | Training loss: 1.217222 | Testing loss: 1.280162
# Iteration: 9001 | Training loss: 1.217006 | Testing loss: 1.287318
# Iteration: 9101 | Training loss: 1.217047 | Testing loss: 1.281382
# Iteration: 9201 | Training loss: 1.217184 | Testing loss: 1.279660
# Iteration: 9301 | Training loss: 1.217392 | Testing loss: 1.283202
# Iteration: 9401 | Training loss: 1.217217 | Testing loss: 1.282369
# Iteration: 9501 | Training loss: 1.217117 | Testing loss: 1.285010
# Iteration: 9601 | Training loss: 1.217133 | Testing loss: 1.290840
# Iteration: 9701 | Training loss: 1.217611 | Testing loss: 1.286487
# Iteration: 9801 | Training loss: 1.217174 | Testing loss: 1.284018
# Iteration: 9901 | Training loss: 1.216990 | Testing loss: 1.279185

# %%
# plot the traing losses and testing losses (0.5 point)
# YOUR CODE HERE
plt.figure(figsize=(8, 6))
plt.plot(range(n_itr), training_losses, label="Training Loss")
plt.plot(range(n_itr), testing_losses, label="Testing Loss")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Training and Testing Loss Curves")
plt.legend()
plt.show()

# %%
# As our model contains a 3 dimensionsional input, we will only plot the relationship between the first variable 'tv' and the target.
# Again plot the train and test data (from Part1), and add a line where the slope and axis intercept are taken from the model parameters w and b
# (0.5 point)
x_vals = torch.linspace(x_train[:, 0].min(), x_train[:, 0].max(), 100).view(-1, 1)
x_vals_full = torch.cat([x_vals, torch.zeros_like(x_vals), torch.zeros_like(x_vals)], dim=1)
y_vals = model(x_vals_full)

# YOUR CODE HERE
plt.figure(figsize=(14, 8))
plt.scatter(x_train[:, 0].numpy(), y_train.numpy(), color="blue", label="Training Data",s=10)
plt.scatter(x_test[:, 0].numpy(), y_test.numpy(), color="red", label="Testing Data")
plt.plot(x_vals.detach().numpy(), y_vals.detach().numpy(), color="orange", label="Trained Model")

plt.xlabel("TV Advertisement Budget")
plt.ylabel("Sales")
plt.title("Training Data, Testing Data, and Trained Model Curve")
plt.legend()
plt.show()
